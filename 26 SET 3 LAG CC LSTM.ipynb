# %% [markdown]
# # Long Short-Term Memory (LSTM) for Wind Speed Forecasting
# ## Dataset 1
#
# This notebook implements LSTM-based wind speed forecasting with four modelling strategies:
# 1. **Original Model** – Manually specified architecture (no tuning)
# 2. **Grid Search** – Exhaustive hyperparameter search with TimeSeriesSplit CV via scikeras
# 3. **Randomized Search** – Stochastic hyperparameter search with TimeSeriesSplit CV via scikeras
# 4. **Optuna** – TPE-based Bayesian hyperparameter optimisation with TimeSeriesSplit CV
#
# **Key design decisions:**
# - First 80% of observations → training; last 20% → testing (chronological, no shuffling)
# - Hyperparameter tuning is performed **exclusively on training data** using `TimeSeriesSplit` (5 folds)
# - `StandardScaler` is **fit on training data only** and reused across ALL sections — prevents data leakage
# - LSTM input shape: `(samples, timesteps=1, features)` — single-step formulation
# - `shuffle=False` in all `.fit()` calls — preserves temporal ordering
# - Global random seed: **42**

# %% [markdown]
# # ─────────────────────────────────────────
# # SECTION 0 — PACKAGE INSTALLATION
# # ─────────────────────────────────────────

# %%
# !pip install -U scikit-learn scikeras

# !pip install scikeras

import sklearn
import scikeras

print("scikit-learn version:", sklearn.__version__)
print("scikeras version:", scikeras.__version__)
#scikit-learn >= 1.2.0
#scikeras >= 0.10.0
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (1.8.0)
# Requirement already satisfied: scikeras in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: numpy>=1.24.1 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (2.0.2)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikeras) (3.10.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (3.15.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.19.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.5.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (26.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->keras>=3.2.0->scikeras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# Requirement already satisfied: scikeras in /usr/local/lib/python3.12/dist-packages (0.13.0)
# Requirement already satisfied: keras>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikeras) (3.10.0)
# Requirement already satisfied: scikit-learn>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from scikeras) (1.8.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (1.4.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (2.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (3.15.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.19.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (0.5.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras>=3.2.0->scikeras) (26.0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.4.2->scikeras) (3.6.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from optree->keras>=3.2.0->scikeras) (4.15.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.2.0->scikeras) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.2.0->scikeras) (0.1.2)
# scikit-learn version: 1.8.0
# scikeras version: 0.13.0

# %%
# Install required packages (run once)
# !pip install statsmodels optuna tabulate scikeras --quiet
# !pip install tensorflow --quiet

# %%
! pip instal optuna
# Out:
# ERROR: unknown command "instal" - maybe you meant "install"

# %% [markdown]
# # ─────────────────────────────────────────
# # SECTION 1 — IMPORTS & GLOBAL SETTINGS
# # ─────────────────────────────────────────

# %%
# Standard libraries
import sys
import os
import random
import warnings
warnings.filterwarnings('ignore')

# Data manipulation
import pandas as pd
import numpy as np

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Scikit-learn — preprocessing & model selection
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import (
    TimeSeriesSplit, GridSearchCV, RandomizedSearchCV
)
from sklearn.metrics import (
    mean_squared_error, mean_absolute_error, r2_score
)
from sklearn.inspection import permutation_importance

# Scipy — statistical distributions for RandomizedSearchCV
from scipy.stats import randint, uniform

# TensorFlow / Keras — LSTM model
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout
from tensorflow.keras.optimizers import Adam

# scikeras — scikit-learn wrapper for Keras models
from scikeras.wrappers import KerasRegressor

# Optuna — Bayesian hyperparameter optimisation
import optuna
optuna.logging.set_verbosity(optuna.logging.WARNING)  # Suppress verbose trial logs

# Tabulate — pretty-print summary tables
from tabulate import tabulate

# ── Global random seed (reproducibility) ──
# Set seed for Python, NumPy, and TensorFlow to ensure reproducible results
RANDOM_SEED = 42
random.seed(RANDOM_SEED)
np.random.seed(RANDOM_SEED)
tf.random.set_seed(RANDOM_SEED)
os.environ['PYTHONHASHSEED'] = str(RANDOM_SEED)

print(f'Random seed set to: {RANDOM_SEED}')
print(f'TensorFlow version : {tf.__version__}')
# Out:
# Random seed set to: 42
# TensorFlow version : 2.19.0

# %% [markdown]
# # ─────────────────────────────────────────
# # SECTION 2 — DATA LOADING
# # ─────────────────────────────────────────

# %%
# Load dataset from Google Drive
# Source: https://drive.google.com/file/d/1c5KmcFD1TOsqASqzy0KiYo-7IzgBFuhk
file_id = '1c5KmcFD1TOsqASqzy0KiYo-7IzgBFuhk'
download_url = f'https://drive.google.com/uc?id={file_id}'

df = pd.read_csv(download_url)

# Backup original DataFrame before any transformation
df_backup = df.copy()

# Create a proper datetime index from year / month / day columns
df['Date'] = pd.to_datetime({
    'year': df['YEAR'],
    'month': df['MO'],
    'day': df['DY']
})
df = df.set_index('Date')

# Drop raw date component columns (now encoded in the index)
df = df.drop(columns=['YEAR', 'MO', 'DY'])

print('Dataset shape:', df.shape)
print('Columns:', df.columns.tolist())
df.head()
# Out:
# Dataset shape: (4015, 14)
# Columns: ['WS10M_lag1', 'RH', 'MIN_TEMP', 'PREC', 'WD_sin', 'SURF_PRESSURE_DIFF', 'AVG_TEMP', 'WD_cos', 'RH_lag1', 'MONOSOON_SEASON_Southwest_Monsoon', 'MAX_TEMP', 'SL_PRESSURE_lag1', 'CLOUD_COVER', 'WS10M']
#             WS10M_lag1     RH  MIN_TEMP   PREC    WD_sin  SURF_PRESSURE_DIFF  \
# Date
# 2013-01-03        4.25  86.26     23.42  13.42  0.439939                0.03
# 2013-01-04        4.75  86.31     22.93   8.79  0.424199               -0.03
# 2013-01-05        5.74  86.88     22.17   2.60  0.563526               -0.15
# 2013-01-06        5.79  88.09     23.47   1.65  0.460200               -0.03
# 2013-01-07        4.52  93.04     24.04  27.41  0.368125               -0.01
#
#             AVG_TEMP    WD_cos  RH_lag1  MONOSOON_SEASON_Southwest_Monsoon  \
# Date
# 2013-01-03      26.4  0.898028    86.19                                  0
# 2013-01-04      25.1  0.905569    86.26                                  0
# 2013-01-05      26.9  0.826098    86.31                                  0
# 2013-01-06      27.3  0.887815    86.88                                  0
# 2013-01-07      25.9  0.929776    88.09                                  0
#
#             MAX_TEMP  SL_PRESSURE_lag1  CLOUD_COVER  WS10M
# Date
# 2013-01-03     28.38            1010.4          8.0   4.75
# 2013-01-04     27.58            1011.0          8.0   5.74
# 2013-01-05     26.16            1010.1          8.0   5.79
# 2013-01-06     27.75            1007.5          7.0   4.52
# 2013-01-07     26.70            1008.2          8.0   4.66

# %% [markdown]
# # ─────────────────────────────────────────
# # SECTION 3 — TRAIN / TEST SPLIT
# # ─────────────────────────────────────────

# %%
# Target variable: wind speed at 10 m (WS10M)
# Features: all remaining meteorological predictors

X = df.drop(columns=['WS10M'])   # Feature matrix
y = df['WS10M']                  # Target vector

# ── Chronological 80/20 split — NO random shuffling (time series integrity) ──
split_index = int(len(X) * 0.8)  # 80% train, 20% test

X_train = X.iloc[:split_index]   # Training features
y_train = y.iloc[:split_index]   # Training target

X_test  = X.iloc[split_index:]   # Testing features
y_test  = y.iloc[split_index:]   # Testing target

print(f'Total samples : {len(df)}')
print(f'Training set  : {X_train.shape[0]} samples ({X_train.index[0].date()} → {X_train.index[-1].date()})')
print(f'Testing set   : {X_test.shape[0]}  samples ({X_test.index[0].date()} → {X_test.index[-1].date()})')
# Out:
# Total samples : 4015
# Training set  : 3212 samples (2013-01-03 → 2021-10-19)
# Testing set   : 803  samples (2021-10-20 → 2023-12-31)

# %% [markdown]
# # ─────────────────────────────────────────
# # SECTION 4 — FEATURE SCALING & LSTM RESHAPING
# # ─────────────────────────────────────────

# %%
# ── IMPORTANT: Scaler is fit on TRAINING DATA ONLY to prevent data leakage ──
# The same scaler parameters (mean, std) are applied to the test set.
# This single scaler instance is reused across ALL four modelling sections.

scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)   # Fit on train, then transform
X_test_scaled  = scaler.transform(X_test)        # Transform test using train statistics only

# ── Reshape for LSTM: (samples, timesteps=1, features) ──
# timesteps=1 corresponds to a single-step (non-sequence) formulation.
# Each row becomes one time step with all features as input channels.
X_train_lstm = np.expand_dims(X_train_scaled, axis=1)  # Shape: (n_train, 1, n_features)
X_test_lstm  = np.expand_dims(X_test_scaled,  axis=1)  # Shape: (n_test,  1, n_features)

# ── Targets as flat numpy arrays (LSTM output is 1D regression) ──
y_train_arr = y_train.values.flatten()
y_test_arr  = y_test.values.flatten()

n_features = X_train_lstm.shape[2]  # Stored for model building

print('Scaling and reshaping complete.')
print(f'X_train_lstm shape : {X_train_lstm.shape}')
print(f'X_test_lstm  shape : {X_test_lstm.shape}')
print(f'Number of features : {n_features}')
# Out:
# Scaling and reshaping complete.
# X_train_lstm shape : (3212, 1, 13)
# X_test_lstm  shape : (803, 1, 13)
# Number of features : 13

# %% [markdown]
# # ─────────────────────────────────────────
# # SECTION 5 — HELPER FUNCTIONS
# # ─────────────────────────────────────────

# %%
def evaluate_metrics(y_true, y_pred, label=''):
    """
    Compute and print regression performance metrics.

    Parameters
    ----------
    y_true : array-like  — Ground-truth target values
    y_pred : array-like  — Model predictions
    label  : str         — Prefix label for printed output

    Returns
    -------
    Tuple: (MSE, RMSE, MAE, MAPE, R²)
    """
    y_true = np.array(y_true).flatten()
    y_pred = np.array(y_pred).flatten()

    mse  = mean_squared_error(y_true, y_pred)
    rmse = np.sqrt(mse)
    mae  = mean_absolute_error(y_true, y_pred)
    # MAPE: guard against division by zero using np.where
    mape = np.mean(
        np.where(np.abs(y_true) > 1e-8,
                 np.abs((y_true - y_pred) / y_true) * 100,
                 0.0)
    )
    r2   = r2_score(y_true, y_pred)

    print(f'{label} MSE  : {mse:.4f}')
    print(f'{label} RMSE : {rmse:.4f}')
    print(f'{label} MAE  : {mae:.4f}')
    print(f'{label} MAPE : {mape:.2f}%')
    print(f'{label} R²   : {r2:.4f}')
    return mse, rmse, mae, mape, r2


def plot_actual_vs_predicted(y_true, y_pred, title, color='blue'):
    """
    Line plot of actual vs predicted values on the test set.

    Parameters
    ----------
    y_true : array-like — Actual target values
    y_pred : array-like — Predicted target values
    title  : str        — Plot title
    color  : str        — Line colour for predictions
    """
    plt.figure(figsize=(12, 5))
    plt.plot(np.array(y_true).flatten(), label='Actual',    color='black', linewidth=2)
    plt.plot(np.array(y_pred).flatten(), label='Predicted', color=color,   linewidth=2, linestyle='--')
    plt.title(title, fontsize=13)
    plt.xlabel('Observation Index')
    plt.ylabel('Wind Speed (WS10M)')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()


def plot_training_history(history, title='LSTM Training History'):
    """
    Plot training and validation loss curves.

    Parameters
    ----------
    history : keras History object — returned by model.fit()
    title   : str                  — Plot title
    """
    plt.figure(figsize=(9, 4))
    plt.plot(history.history['loss'],     label='Train Loss', linewidth=2)
    plt.plot(history.history['val_loss'], label='Val Loss',   linewidth=2, linestyle='--')
    plt.title(title, fontsize=13)
    plt.xlabel('Epoch')
    plt.ylabel('MSE Loss')
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.5)
    plt.tight_layout()
    plt.show()


# Storage dictionary for the final comparison table
results_store = {}

print('Helper functions defined.')
# Out:
# Helper functions defined.

# %% [markdown]
# # ─────────────────────────────────────────
# # SECTION 6 — LSTM: ORIGINAL MODEL
# #             (No hyperparameter optimisation)
# # ─────────────────────────────────────────

# %%
# ── LSTM with manually specified default architecture ──
# 50 LSTM units with tanh activation (standard for LSTM gates)
# Adam optimiser with learning_rate=0.001 (widely used default)
# validation_split=0.1 uses the LAST 10% of training data as validation
# shuffle=False is CRITICAL — preserves the temporal order of samples

tf.random.set_seed(RANDOM_SEED)

lstm_original = Sequential([
    LSTM(50, activation='tanh',
         input_shape=(X_train_lstm.shape[1], X_train_lstm.shape[2])),
    Dense(1)   # Single output neuron for regression
])
lstm_original.compile(optimizer=Adam(learning_rate=0.001), loss='mse')
lstm_original.summary()

# Train the model
# shuffle=False: CRITICAL for time series — must not mix future into past
history_orig = lstm_original.fit(
    X_train_lstm, y_train_arr,
    epochs=100,
    batch_size=32,
    validation_split=0.1,   # Last 10% of train used for validation monitoring
    shuffle=False,           # Preserve temporal ordering
    verbose=1
)

# Plot training loss curves
plot_training_history(history_orig, title='LSTM Original — Training History')

# Predict on both splits
y_train_pred_orig = lstm_original.predict(X_train_lstm).flatten()
y_test_pred_orig  = lstm_original.predict(X_test_lstm).flatten()

# ── Performance Evaluation ──
print('=' * 50)
print('  LSTM — ORIGINAL MODEL (Default Parameters)')
print('=' * 50)
print('\n[Training Set]')
tr_mse, tr_rmse, tr_mae, tr_mape, tr_r2 = evaluate_metrics(
    y_train_arr, y_train_pred_orig, label='Train')
print('\n[Test Set]')
te_mse, te_rmse, te_mae, te_mape, te_r2 = evaluate_metrics(
    y_test_arr, y_test_pred_orig, label='Test ')

# Store results for summary table
results_store['Original Model'] = {
    'Train RMSE': tr_rmse, 'Train MAE': tr_mae,
    'Train MAPE': tr_mape, 'Train R2' : tr_r2,
    'Test RMSE' : te_rmse, 'Test MAE' : te_mae,
    'Test MAPE' : te_mape, 'Test R2'  : te_r2
}

# Comparison DataFrame — first 20 predictions
comparison_df = pd.DataFrame({
    'Actual'   : y_test_arr,
    'Predicted': y_test_pred_orig
}, index=y_test.index)
print('\nFirst 20 test predictions:')
print(comparison_df.head(20))

# ── Actual vs Predicted Plot ──
plot_actual_vs_predicted(
    y_test_arr, y_test_pred_orig,
    title='Actual vs Predicted — LSTM Original Model (Test Set)',
    color='steelblue'
)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 50)             │        12,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │            51 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 12,851 (50.20 KB)
#  Trainable params: 12,851 (50.20 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 4s 7ms/step - loss: 19.2337 - val_loss: 16.3055
# Epoch 2/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 13.1742 - val_loss: 7.5762
# Epoch 3/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 5.7878 - val_loss: 2.6249
# Epoch 4/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2989 - val_loss: 1.4382
# Epoch 5/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.3465 - val_loss: 1.1124
# Epoch 6/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.0254 - val_loss: 0.9631
# Epoch 7/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.8622 - val_loss: 0.8619
# Epoch 8/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.7483 - val_loss: 0.7833
# Epoch 9/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6605 - val_loss: 0.7217
# Epoch 10/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5935 - val_loss: 0.6763
# Epoch 11/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5450 - val_loss: 0.6451
# Epoch 12/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.5110 - val_loss: 0.6247
# Epoch 13/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4866 - val_loss: 0.6112
# Epoch 14/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4686 - val_loss: 0.6022
# Epoch 15/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4548 - val_loss: 0.5958
# Epoch 16/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4439 - val_loss: 0.5908
# Epoch 17/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4350 - val_loss: 0.5867
# Epoch 18/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4276 - val_loss: 0.5832
# Epoch 19/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4215 - val_loss: 0.5801
# Epoch 20/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4164 - val_loss: 0.5773
# Epoch 21/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4120 - val_loss: 0.5747
# Epoch 22/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4083 - val_loss: 0.5724
# Epoch 23/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4052 - val_loss: 0.5703
# Epoch 24/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4025 - val_loss: 0.5684
# Epoch 25/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4001 - val_loss: 0.5668
# Epoch 26/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3980 - val_loss: 0.5652
# Epoch 27/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3962 - val_loss: 0.5638
# Epoch 28/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3946 - val_loss: 0.5625
# Epoch 29/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3931 - val_loss: 0.5613
# Epoch 30/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3917 - val_loss: 0.5602
# Epoch 31/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3904 - val_loss: 0.5591
# Epoch 32/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3893 - val_loss: 0.5580
# Epoch 33/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3882 - val_loss: 0.5570
# Epoch 34/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3871 - val_loss: 0.5560
# Epoch 35/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3861 - val_loss: 0.5550
# Epoch 36/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3852 - val_loss: 0.5540
# Epoch 37/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3842 - val_loss: 0.5531
# Epoch 38/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3833 - val_loss: 0.5521
# Epoch 39/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3824 - val_loss: 0.5512
# Epoch 40/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3816 - val_loss: 0.5503
# Epoch 41/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3807 - val_loss: 0.5494
# Epoch 42/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3799 - val_loss: 0.5486
# Epoch 43/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3791 - val_loss: 0.5477
# Epoch 44/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3783 - val_loss: 0.5469
# Epoch 45/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3775 - val_loss: 0.5461
# Epoch 46/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3767 - val_loss: 0.5454
# Epoch 47/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3759 - val_loss: 0.5446
# Epoch 48/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3751 - val_loss: 0.5439
# Epoch 49/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3743 - val_loss: 0.5432
# Epoch 50/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3735 - val_loss: 0.5425
# Epoch 51/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3727 - val_loss: 0.5419
# Epoch 52/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3719 - val_loss: 0.5412
# Epoch 53/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3711 - val_loss: 0.5406
# Epoch 54/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3704 - val_loss: 0.5400
# Epoch 55/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3696 - val_loss: 0.5395
# Epoch 56/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3688 - val_loss: 0.5389
# Epoch 57/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3680 - val_loss: 0.5383
# Epoch 58/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3672 - val_loss: 0.5378
# Epoch 59/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3664 - val_loss: 0.5373
# Epoch 60/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3656 - val_loss: 0.5368
# Epoch 61/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3648 - val_loss: 0.5363
# Epoch 62/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3640 - val_loss: 0.5358
# Epoch 63/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3632 - val_loss: 0.5353
# Epoch 64/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3624 - val_loss: 0.5348
# Epoch 65/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3616 - val_loss: 0.5344
# Epoch 66/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3608 - val_loss: 0.5339
# Epoch 67/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3600 - val_loss: 0.5334
# Epoch 68/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3592 - val_loss: 0.5330
# Epoch 69/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3584 - val_loss: 0.5325
# Epoch 70/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3576 - val_loss: 0.5321
# Epoch 71/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3567 - val_loss: 0.5317
# Epoch 72/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3559 - val_loss: 0.5312
# Epoch 73/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3551 - val_loss: 0.5308
# Epoch 74/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3543 - val_loss: 0.5304
# Epoch 75/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3535 - val_loss: 0.5300
# Epoch 76/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3527 - val_loss: 0.5295
# Epoch 77/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3519 - val_loss: 0.5291
# Epoch 78/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3511 - val_loss: 0.5287
# Epoch 79/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3503 - val_loss: 0.5282
# Epoch 80/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3495 - val_loss: 0.5278
# Epoch 81/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3487 - val_loss: 0.5273
# Epoch 82/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3479 - val_loss: 0.5269
# Epoch 83/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3471 - val_loss: 0.5264
# Epoch 84/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3463 - val_loss: 0.5260
# Epoch 85/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3455 - val_loss: 0.5255
# Epoch 86/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3447 - val_loss: 0.5251
# Epoch 87/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3439 - val_loss: 0.5246
# Epoch 88/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3432 - val_loss: 0.5242
# Epoch 89/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3424 - val_loss: 0.5237
# Epoch 90/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3416 - val_loss: 0.5232
# Epoch 91/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3409 - val_loss: 0.5228
# Epoch 92/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3401 - val_loss: 0.5224
# Epoch 93/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3394 - val_loss: 0.5219
# Epoch 94/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3386 - val_loss: 0.5215
# Epoch 95/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3379 - val_loss: 0.5211
# Epoch 96/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3371 - val_loss: 0.5206
# Epoch 97/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3364 - val_loss: 0.5202
# Epoch 98/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3357 - val_loss: 0.5198
# Epoch 99/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3350 - val_loss: 0.5194
# Epoch 100/100
# 91/91 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3343 - val_loss: 0.5190
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# ==================================================
#   LSTM — ORIGINAL MODEL (Default Parameters)
# ==================================================
#
# [Training Set]
# Train MSE  : 0.3663
# Train RMSE : 0.6053
# Train MAE  : 0.4732
# Train MAPE : 12.81%
# Train R²   : 0.8546
#
# [Test Set]
# Test  MSE  : 0.5919
# Test  RMSE : 0.7694
# Test  MAE  : 0.5943
# Test  MAPE : 15.50%
# Test  R²   : 0.7545
#
# First 20 test predictions:
#             Actual  Predicted
# Date
# 2021-10-20    2.82   3.547431
# 2021-10-21    2.79   3.237447
# 2021-10-22    2.72   2.421080
# 2021-10-23    4.30   2.509242
# 2021-10-24    3.74   3.182901
# 2021-10-25    2.69   3.415492
# 2021-10-26    2.37   3.358165
# 2021-10-27    2.30   2.458440
# 2021-10-28    3.50   3.360060
# 2021-10-29    4.15   3.313588
# 2021-10-30    1.97   3.160000
# 2021-10-31    5.60   4.268657
# 2021-11-01    6.11   3.866641
# 2021-11-02    2.57   4.036925
# 2021-11-03    3.27   3.601038
# 2021-11-04    3.36   2.879549
# 2021-11-05    3.55   3.212236
# 2021-11-06    4.03   4.259870
# 2021-11-07    5.18   4.237795
# 2021-11-08    5.81   4.856713

# %% [markdown]
# # ─────────────────────────────────────────
# # SECTION 7 — LSTM: GRID SEARCH
# #             (Exhaustive hyperparameter search)
# # ─────────────────────────────────────────

# %%
# ── Model builder function for scikeras ──
# scikeras requires a callable that accepts hyperparameters and returns a compiled model.
def build_lstm_grid(units=64, dropout_rate=0.2, learning_rate=0.001):
    """
    Build and compile an LSTM model for use with KerasRegressor (scikeras).

    Parameters
    ----------
    units         : int   — Number of LSTM units
    dropout_rate  : float — Dropout rate after LSTM layer
    learning_rate : float — Adam optimiser learning rate
    """
    tf.random.set_seed(RANDOM_SEED)
    model = Sequential([
        LSTM(units, activation='tanh', return_sequences=False,
             input_shape=(1, n_features)),
        Dropout(dropout_rate),
        Dense(1)
    ])
    model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')
    return model

# Wrap Keras model for scikit-learn compatibility via scikeras
lstm_regressor_grid = KerasRegressor(
    model=build_lstm_grid,
    verbose=0,
    random_state=RANDOM_SEED
)

# ── Hyperparameter grid for exhaustive search ──
param_grid = {
    'model__units'        : [32, 64, 128],
    'model__dropout_rate' : [0.1, 0.2, 0.3],
    'model__learning_rate': [0.001, 0.005],
    'batch_size'          : [16, 32],
    'epochs'              : [50, 100]
}

# ── TimeSeriesSplit: 5-fold CV applied to TRAINING DATA ONLY ──
# Ensures future observations never appear in a validation fold during tuning.
# NOTE: standard GridSearchCV with cv=3 (KFold) was in the original code —
# that randomly splits time series data and causes data leakage.
# Replaced with TimeSeriesSplit for methodological correctness.
tscv = TimeSeriesSplit(n_splits=5)

grid_search = GridSearchCV(
    estimator=lstm_regressor_grid,
    param_grid=param_grid,
    scoring='neg_mean_squared_error',
    cv=tscv,
    verbose=1,
    n_jobs=1   # n_jobs=1 required for TF/Keras models (GPU thread safety)
)

# Fit Grid Search on LSTM-shaped training data only
grid_search.fit(X_train_lstm, y_train_arr)

print('\nBest Parameters (Grid Search):')
print(grid_search.best_params_)
print(f'Best CV Score (neg-MSE): {grid_search.best_score_:.4f}')

# ── Predict using best estimator refitted on full training set ──
best_lstm_grid = grid_search.best_estimator_
y_train_pred_grid = best_lstm_grid.predict(X_train_lstm).flatten()
y_test_pred_grid  = best_lstm_grid.predict(X_test_lstm).flatten()

# ── Performance Evaluation ──
print('\n' + '=' * 50)
print('  LSTM — GRID SEARCH (Optimised Parameters)')
print('=' * 50)
print('\n[Training Set]')
tr_mse, tr_rmse, tr_mae, tr_mape, tr_r2 = evaluate_metrics(
    y_train_arr, y_train_pred_grid, label='Train')
print('\n[Test Set]')
te_mse, te_rmse, te_mae, te_mape, te_r2 = evaluate_metrics(
    y_test_arr, y_test_pred_grid, label='Test ')

# Store results for summary table
results_store['Grid Search'] = {
    'Train RMSE': tr_rmse, 'Train MAE': tr_mae,
    'Train MAPE': tr_mape, 'Train R2' : tr_r2,
    'Test RMSE' : te_rmse, 'Test MAE' : te_mae,
    'Test MAPE' : te_mape, 'Test R2'  : te_r2
}

# ── Actual vs Predicted Plot ──
plot_actual_vs_predicted(
    y_test_arr, y_test_pred_grid,
    title='Actual vs Predicted — LSTM Grid Search (Test Set)',
    color='blue'
)
# Out:
# Fitting 5 folds for each of 72 candidates, totalling 360 fits
#
# Best Parameters (Grid Search):
# {'batch_size': 32, 'epochs': 100, 'model__dropout_rate': 0.2, 'model__learning_rate': 0.001, 'model__units': 128}
# Best CV Score (neg-MSE): -0.4814
#
# ==================================================
#   LSTM — GRID SEARCH (Optimised Parameters)
# ==================================================
#
# [Training Set]
# Train MSE  : 0.3658
# Train RMSE : 0.6048
# Train MAE  : 0.4741
# Train MAPE : 13.16%
# Train R²   : 0.8548
#
# [Test Set]
# Test  MSE  : 0.5308
# Test  RMSE : 0.7286
# Test  MAE  : 0.5667
# Test  MAPE : 15.13%
# Test  R²   : 0.7799

# %% [markdown]
# # ─────────────────────────────────────────
# # SECTION 8 — LSTM: RANDOMIZED SEARCH
# #             (Stochastic hyperparameter search)
# # ─────────────────────────────────────────

# %%
# ── Model builder function for scikeras ──
def build_lstm_random(units=50, dropout_rate=0.2, learning_rate=0.001):
    """
    Build and compile an LSTM model for use with KerasRegressor (scikeras).

    Parameters
    ----------
    units         : int   — Number of LSTM units
    dropout_rate  : float — Dropout rate after LSTM layer
    learning_rate : float — Adam optimiser learning rate
    """
    tf.random.set_seed(RANDOM_SEED)
    model = Sequential([
        LSTM(units, input_shape=(1, n_features)),
        Dropout(dropout_rate),
        Dense(1)   # Regression output
    ])
    model.compile(loss='mse', optimizer=Adam(learning_rate=learning_rate))
    return model

# Wrap Keras model for scikit-learn compatibility via scikeras
lstm_regressor_random = KerasRegressor(
    model=build_lstm_random,
    verbose=0,
    random_state=RANDOM_SEED
)

# ── Continuous and discrete distributions for random sampling ──
param_dist = {
    'model__units'        : randint(20, 151),          # Uniform integer in [20, 150]
    'model__dropout_rate' : uniform(0.1, 0.3),         # Continuous in [0.1, 0.4]
    'model__learning_rate': uniform(1e-4, 9e-3),       # Continuous in [0.0001, 0.0091]
    'batch_size'          : randint(16, 65),            # Uniform integer in [16, 64]
    'epochs'              : randint(50, 151)            # Uniform integer in [50, 150]
}

# ── TimeSeriesSplit: 5-fold CV applied to TRAINING DATA ONLY ──
# Original code used cv=3 (KFold) which randomly shuffles time series — data leakage.
# Replaced with TimeSeriesSplit for methodological correctness.
tscv = TimeSeriesSplit(n_splits=5)

random_search = RandomizedSearchCV(
    estimator=lstm_regressor_random,
    param_distributions=param_dist,
    n_iter=20,                      # Number of random parameter combinations to try
    scoring='neg_mean_squared_error',
    cv=tscv,
    verbose=1,
    random_state=RANDOM_SEED,
    n_jobs=1    # n_jobs=1 required for TF/Keras models (GPU thread safety)
)

# Fit Randomized Search on LSTM-shaped training data only
random_search.fit(X_train_lstm, y_train_arr)

print('\nBest Parameters (Randomized Search):')
print(random_search.best_params_)
print(f'Best CV Score (neg-MSE): {random_search.best_score_:.4f}')

# ── Predict using best estimator refitted on full training set ──
best_lstm_random = random_search.best_estimator_
y_train_pred_random = best_lstm_random.predict(X_train_lstm).flatten()
y_test_pred_random  = best_lstm_random.predict(X_test_lstm).flatten()

# ── Performance Evaluation ──
print('\n' + '=' * 50)
print('  LSTM — RANDOMIZED SEARCH (Optimised Parameters)')
print('=' * 50)
print('\n[Training Set]')
tr_mse, tr_rmse, tr_mae, tr_mape, tr_r2 = evaluate_metrics(
    y_train_arr, y_train_pred_random, label='Train')
print('\n[Test Set]')
te_mse, te_rmse, te_mae, te_mape, te_r2 = evaluate_metrics(
    y_test_arr, y_test_pred_random, label='Test ')

# Store results for summary table
results_store['Randomized Search'] = {
    'Train RMSE': tr_rmse, 'Train MAE': tr_mae,
    'Train MAPE': tr_mape, 'Train R2' : tr_r2,
    'Test RMSE' : te_rmse, 'Test MAE' : te_mae,
    'Test MAPE' : te_mape, 'Test R2'  : te_r2
}

# ── Actual vs Predicted Plot ──
plot_actual_vs_predicted(
    y_test_arr, y_test_pred_random,
    title='Actual vs Predicted — LSTM Randomized Search (Test Set)',
    color='darkorange'
)
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
#
# Best Parameters (Randomized Search):
# {'batch_size': 62, 'epochs': 84, 'model__dropout_rate': np.float64(0.37279612062363465), 'model__learning_rate': np.float64(0.002429019834400152), 'model__units': 123}
# Best CV Score (neg-MSE): -0.4827
#
# ==================================================
#   LSTM — RANDOMIZED SEARCH (Optimised Parameters)
# ==================================================
#
# [Training Set]
# Train MSE  : 0.3778
# Train RMSE : 0.6147
# Train MAE  : 0.4805
# Train MAPE : 13.23%
# Train R²   : 0.8500
#
# [Test Set]
# Test  MSE  : 0.5308
# Test  RMSE : 0.7286
# Test  MAE  : 0.5631
# Test  MAPE : 14.99%
# Test  R²   : 0.7799

# %% [markdown]
# # ─────────────────────────────────────────
# # SECTION 9 — LSTM: OPTUNA
# #             (TPE-based Bayesian optimisation)
# # ─────────────────────────────────────────

# %%
# ── Optuna objective function ──
# Performs TimeSeriesSplit CV on TRAINING DATA ONLY.
# Test data is NEVER touched during optimisation — no data leakage.

def lstm_objective(trial):
    # Suggest hyperparameters for this trial
    units         = trial.suggest_int('units',      20, 150)
    dropout_rate  = trial.suggest_float('dropout_rate', 0.1, 0.5)
    learning_rate = trial.suggest_float('learning_rate', 1e-4, 1e-2, log=True)
    batch_size    = trial.suggest_categorical('batch_size', [16, 32, 64])
    epochs        = trial.suggest_int('epochs', 50, 150)

    tscv = TimeSeriesSplit(n_splits=5)
    fold_rmse = []

    for train_idx, val_idx in tscv.split(X_train_lstm):
        # ── Index into pre-scaled, pre-reshaped numpy arrays ──
        # No re-fitting of the scaler inside CV folds (would leak val statistics).
        X_fold_tr,  X_fold_val  = X_train_lstm[train_idx], X_train_lstm[val_idx]
        y_fold_tr,  y_fold_val  = y_train_arr[train_idx],  y_train_arr[val_idx]

        tf.random.set_seed(RANDOM_SEED)
        model = Sequential([
            LSTM(units, activation='tanh',
                 input_shape=(1, n_features)),
            Dropout(dropout_rate),
            Dense(1)
        ])
        model.compile(optimizer=Adam(learning_rate=learning_rate), loss='mse')

        # shuffle=False: preserves temporal ordering within each fold
        model.fit(
            X_fold_tr, y_fold_tr,
            epochs=epochs,
            batch_size=batch_size,
            verbose=0,
            shuffle=False
        )

        preds = model.predict(X_fold_val, verbose=0).flatten()
        fold_rmse.append(np.sqrt(mean_squared_error(y_fold_val, preds)))

    return np.mean(fold_rmse)   # Minimise mean RMSE across folds


# ── Run Optuna study ──
# TPE (Tree-structured Parzen Estimator) sampler is more sample-efficient
# than a purely random sampler and is the recommended Optuna default.
study = optuna.create_study(
    direction='minimize',
    sampler=optuna.samplers.TPESampler(seed=RANDOM_SEED)
)
study.optimize(lstm_objective, n_trials=30, timeout=600)  # Max 30 trials or 10 min

print('\nBest Trial:')
print(f'  Value (mean CV RMSE): {study.best_trial.value:.4f}')
print('\nBest Parameters (Optuna):')
print(study.best_params)

# ── Refit final LSTM on FULL training set using best hyperparameters ──
best_params = study.best_params

tf.random.set_seed(RANDOM_SEED)
best_lstm_optuna = Sequential([
    LSTM(best_params['units'], activation='tanh',
         input_shape=(1, n_features)),
    Dropout(best_params['dropout_rate']),
    Dense(1)
])
best_lstm_optuna.compile(
    optimizer=Adam(learning_rate=best_params['learning_rate']),
    loss='mse'
)

# Train on full training set — shuffle=False preserves temporal ordering
history_optuna = best_lstm_optuna.fit(
    X_train_lstm, y_train_arr,
    epochs=best_params['epochs'],
    batch_size=best_params['batch_size'],
    validation_split=0.1,
    verbose=1,
    shuffle=False
)

# Plot training loss curves
plot_training_history(history_optuna, title='LSTM Optuna — Training History')

# Predict on both splits
y_train_pred_optuna = best_lstm_optuna.predict(X_train_lstm).flatten()
y_test_pred_optuna  = best_lstm_optuna.predict(X_test_lstm).flatten()

# ── Performance Evaluation ──
print('\n' + '=' * 50)
print('  LSTM — OPTUNA (Optimised Parameters)')
print('=' * 50)
print('\n[Training Set]')
tr_mse, tr_rmse, tr_mae, tr_mape, tr_r2 = evaluate_metrics(
    y_train_arr, y_train_pred_optuna, label='Train')
print('\n[Test Set]')
te_mse, te_rmse, te_mae, te_mape, te_r2 = evaluate_metrics(
    y_test_arr, y_test_pred_optuna, label='Test ')

# Store results for summary table
results_store['Optuna'] = {
    'Train RMSE': tr_rmse, 'Train MAE': tr_mae,
    'Train MAPE': tr_mape, 'Train R2' : tr_r2,
    'Test RMSE' : te_rmse, 'Test MAE' : te_mae,
    'Test MAPE' : te_mape, 'Test R2'  : te_r2
}

# ── Actual vs Predicted Plot ──
plot_actual_vs_predicted(
    y_test_arr, y_test_pred_optuna,
    title='Actual vs Predicted — LSTM Optuna (Test Set)',
    color='green'
)

# ── Optuna optimisation history plot ──
optuna.visualization.matplotlib.plot_optimization_history(study)
plt.title('Optuna Optimisation History — LSTM')
plt.tight_layout()
plt.show()
# Out:
# Best Trial:
#   Value (mean CV RMSE): 0.7000
#
# Best Parameters (Optuna):
# {'units': 97, 'dropout_rate': 0.1185801650879991, 'learning_rate': 0.0016409286730647919, 'batch_size': 64, 'epochs': 147}
# Epoch 1/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 19.4326 - val_loss: 16.3420
# Epoch 2/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 13.0837 - val_loss: 6.3826
# Epoch 3/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 4.6876 - val_loss: 1.7867
# Epoch 4/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.7158 - val_loss: 1.1747
# Epoch 5/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 1.1954 - val_loss: 0.9490
# Epoch 6/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.9336 - val_loss: 0.8196
# Epoch 7/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8036 - val_loss: 0.7334
# Epoch 8/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6958 - val_loss: 0.6781
# Epoch 9/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.6322 - val_loss: 0.6393
# Epoch 10/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5690 - val_loss: 0.6148
# Epoch 11/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5430 - val_loss: 0.6004
# Epoch 12/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5250 - val_loss: 0.5931
# Epoch 13/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.5159 - val_loss: 0.5854
# Epoch 14/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4968 - val_loss: 0.5807
# Epoch 15/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4974 - val_loss: 0.5769
# Epoch 16/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4737 - val_loss: 0.5738
# Epoch 17/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4730 - val_loss: 0.5695
# Epoch 18/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4663 - val_loss: 0.5672
# Epoch 19/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4576 - val_loss: 0.5651
# Epoch 20/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4631 - val_loss: 0.5613
# Epoch 21/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4499 - val_loss: 0.5619
# Epoch 22/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4653 - val_loss: 0.5569
# Epoch 23/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4405 - val_loss: 0.5553
# Epoch 24/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4507 - val_loss: 0.5548
# Epoch 25/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4541 - val_loss: 0.5528
# Epoch 26/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4564 - val_loss: 0.5515
# Epoch 27/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4505 - val_loss: 0.5521
# Epoch 28/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4516 - val_loss: 0.5495
# Epoch 29/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4435 - val_loss: 0.5511
# Epoch 30/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4390 - val_loss: 0.5528
# Epoch 31/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4434 - val_loss: 0.5518
# Epoch 32/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4423 - val_loss: 0.5486
# Epoch 33/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4513 - val_loss: 0.5466
# Epoch 34/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4529 - val_loss: 0.5502
# Epoch 35/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4576 - val_loss: 0.5434
# Epoch 36/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4384 - val_loss: 0.5450
# Epoch 37/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4398 - val_loss: 0.5437
# Epoch 38/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4486 - val_loss: 0.5421
# Epoch 39/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4242 - val_loss: 0.5412
# Epoch 40/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4451 - val_loss: 0.5396
# Epoch 41/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4358 - val_loss: 0.5391
# Epoch 42/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4349 - val_loss: 0.5387
# Epoch 43/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4232 - val_loss: 0.5388
# Epoch 44/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4408 - val_loss: 0.5370
# Epoch 45/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4296 - val_loss: 0.5373
# Epoch 46/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4347 - val_loss: 0.5362
# Epoch 47/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4302 - val_loss: 0.5370
# Epoch 48/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4241 - val_loss: 0.5384
# Epoch 49/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4294 - val_loss: 0.5356
# Epoch 50/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4310 - val_loss: 0.5375
# Epoch 51/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.4152 - val_loss: 0.5357
# Epoch 52/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4281 - val_loss: 0.5341
# Epoch 53/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4281 - val_loss: 0.5335
# Epoch 54/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4222 - val_loss: 0.5338
# Epoch 55/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4223 - val_loss: 0.5326
# Epoch 56/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4268 - val_loss: 0.5324
# Epoch 57/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4255 - val_loss: 0.5355
# Epoch 58/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4274 - val_loss: 0.5304
# Epoch 59/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4186 - val_loss: 0.5333
# Epoch 60/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4239 - val_loss: 0.5315
# Epoch 61/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4388 - val_loss: 0.5276
# Epoch 62/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4139 - val_loss: 0.5273
# Epoch 63/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4217 - val_loss: 0.5283
# Epoch 64/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4305 - val_loss: 0.5286
# Epoch 65/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4216 - val_loss: 0.5241
# Epoch 66/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4252 - val_loss: 0.5268
# Epoch 67/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4188 - val_loss: 0.5254
# Epoch 68/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4276 - val_loss: 0.5273
# Epoch 69/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4177 - val_loss: 0.5235
# Epoch 70/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4255 - val_loss: 0.5221
# Epoch 71/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4164 - val_loss: 0.5206
# Epoch 72/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4306 - val_loss: 0.5203
# Epoch 73/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4191 - val_loss: 0.5217
# Epoch 74/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4206 - val_loss: 0.5187
# Epoch 75/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4144 - val_loss: 0.5208
# Epoch 76/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.4245 - val_loss: 0.5181
# Epoch 77/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4139 - val_loss: 0.5141
# Epoch 78/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4109 - val_loss: 0.5196
# Epoch 79/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4093 - val_loss: 0.5213
# Epoch 80/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.4247 - val_loss: 0.5185
# Epoch 81/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.4212 - val_loss: 0.5176
# Epoch 82/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4274 - val_loss: 0.5195
# Epoch 83/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4131 - val_loss: 0.5163
# Epoch 84/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4172 - val_loss: 0.5161
# Epoch 85/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4303 - val_loss: 0.5145
# Epoch 86/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4097 - val_loss: 0.5154
# Epoch 87/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3984 - val_loss: 0.5110
# Epoch 88/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4166 - val_loss: 0.5137
# Epoch 89/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4062 - val_loss: 0.5098
# Epoch 90/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4081 - val_loss: 0.5113
# Epoch 91/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4071 - val_loss: 0.5096
# Epoch 92/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4149 - val_loss: 0.5128
# Epoch 93/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4079 - val_loss: 0.5097
# Epoch 94/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3954 - val_loss: 0.5123
# Epoch 95/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3996 - val_loss: 0.5088
# Epoch 96/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4090 - val_loss: 0.5091
# Epoch 97/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4087 - val_loss: 0.5087
# Epoch 98/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4039 - val_loss: 0.5040
# Epoch 99/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4230 - val_loss: 0.5056
# Epoch 100/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4037 - val_loss: 0.5055
# Epoch 101/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3978 - val_loss: 0.5051
# Epoch 102/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4035 - val_loss: 0.5059
# Epoch 103/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3969 - val_loss: 0.5052
# Epoch 104/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4032 - val_loss: 0.5046
# Epoch 105/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3957 - val_loss: 0.5056
# Epoch 106/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3959 - val_loss: 0.5111
# Epoch 107/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4096 - val_loss: 0.5047
# Epoch 108/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3925 - val_loss: 0.5072
# Epoch 109/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3997 - val_loss: 0.5059
# Epoch 110/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4062 - val_loss: 0.5052
# Epoch 111/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3959 - val_loss: 0.5021
# Epoch 112/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3941 - val_loss: 0.5015
# Epoch 113/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.4031 - val_loss: 0.5013
# Epoch 114/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3995 - val_loss: 0.4994
# Epoch 115/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3845 - val_loss: 0.4986
# Epoch 116/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3960 - val_loss: 0.5033
# Epoch 117/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3968 - val_loss: 0.5017
# Epoch 118/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3929 - val_loss: 0.5020
# Epoch 119/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3834 - val_loss: 0.4988
# Epoch 120/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3969 - val_loss: 0.5047
# Epoch 121/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3985 - val_loss: 0.4983
# Epoch 122/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.3869 - val_loss: 0.5007
# Epoch 123/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.4004 - val_loss: 0.4994
# Epoch 124/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - loss: 0.3962 - val_loss: 0.4991
# Epoch 125/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 0.3886 - val_loss: 0.4983
# Epoch 126/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3843 - val_loss: 0.4985
# Epoch 127/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3903 - val_loss: 0.4978
# Epoch 128/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3837 - val_loss: 0.4976
# Epoch 129/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3891 - val_loss: 0.4974
# Epoch 130/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3845 - val_loss: 0.4994
# Epoch 131/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3910 - val_loss: 0.4970
# Epoch 132/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3847 - val_loss: 0.5006
# Epoch 133/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.3768 - val_loss: 0.4955
# Epoch 134/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3857 - val_loss: 0.4962
# Epoch 135/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3793 - val_loss: 0.4950
# Epoch 136/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3925 - val_loss: 0.4958
# Epoch 137/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3879 - val_loss: 0.4965
# Epoch 138/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3897 - val_loss: 0.4951
# Epoch 139/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3928 - val_loss: 0.4959
# Epoch 140/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3881 - val_loss: 0.4961
# Epoch 141/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3875 - val_loss: 0.4958
# Epoch 142/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3820 - val_loss: 0.4935
# Epoch 143/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3773 - val_loss: 0.4916
# Epoch 144/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3878 - val_loss: 0.4925
# Epoch 145/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3739 - val_loss: 0.4985
# Epoch 146/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3750 - val_loss: 0.4949
# Epoch 147/147
# 46/46 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.3700 - val_loss: 0.4935
# 101/101 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#
# ==================================================
#   LSTM — OPTUNA (Optimised Parameters)
# ==================================================
#
# [Training Set]
# Train MSE  : 0.3600
# Train RMSE : 0.6000
# Train MAE  : 0.4695
# Train MAPE : 12.78%
# Train R²   : 0.8571
#
# [Test Set]
# Test  MSE  : 0.5549
# Test  RMSE : 0.7449
# Test  MAE  : 0.5728
# Test  MAPE : 15.02%
# Test  R²   : 0.7699

# %% [markdown]
# # ─────────────────────────────────────────
# # SECTION 10 — PERFORMANCE COMPARISON TABLE
# #              All four methods side-by-side
# # ─────────────────────────────────────────

# %%
# ── Build the comparison DataFrame ──
methods = ['Original Model', 'Grid Search', 'Randomized Search', 'Optuna']

summary_data = []
for method in methods:
    r = results_store[method]
    summary_data.append({
        'Method'    : method,
        'Train RMSE': round(r['Train RMSE'], 4),
        'Train MAE' : round(r['Train MAE'],  4),
        'Train MAPE': round(r['Train MAPE'], 2),
        'Train R²'  : round(r['Train R2'],   4),
        'Test RMSE' : round(r['Test RMSE'],  4),
        'Test MAE'  : round(r['Test MAE'],   4),
        'Test MAPE' : round(r['Test MAPE'],  2),
        'Test R²'   : round(r['Test R2'],    4)
    })

summary_df = pd.DataFrame(summary_data)

# ── Pretty-print with tabulate ──
print('\n' + '=' * 80)
print('  LSTM PERFORMANCE SUMMARY — DATASET 1')
print('  (80% Train / 20% Test  |  TimeSeriesSplit CV on train only)')
print('=' * 80)
print(tabulate(summary_df, headers='keys', tablefmt='grid',
               showindex=False, floatfmt='.4f'))

# ── Display as styled pandas table ──
display(summary_df.style
        .set_caption('LSTM — Hyperparameter Optimisation Comparison (Dataset 1)')
        .highlight_min(subset=['Test RMSE', 'Test MAE', 'Test MAPE'], color='lightgreen')
        .highlight_max(subset=['Test R²'],                             color='lightgreen')
        .format({
            'Train RMSE': '{:.4f}', 'Train MAE': '{:.4f}',
            'Train MAPE': '{:.2f}', 'Train R²' : '{:.4f}',
            'Test RMSE' : '{:.4f}', 'Test MAE' : '{:.4f}',
            'Test MAPE' : '{:.2f}', 'Test R²'  : '{:.4f}'
        })
)

# ── Bar chart comparison (Test RMSE and Test R²) ──
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

colors = ['#2E86AB', '#A23B72', '#F18F01', '#2D6A4F']

axes[0].bar(summary_df['Method'], summary_df['Test RMSE'], color=colors, edgecolor='black')
axes[0].set_title('Test RMSE by Method', fontsize=13)
axes[0].set_ylabel('RMSE')
axes[0].set_xticklabels(summary_df['Method'], rotation=15, ha='right')
axes[0].grid(axis='y', linestyle='--', alpha=0.5)

axes[1].bar(summary_df['Method'], summary_df['Test R²'], color=colors, edgecolor='black')
axes[1].set_title('Test R² by Method', fontsize=13)
axes[1].set_ylabel('R²')
axes[1].set_xticklabels(summary_df['Method'], rotation=15, ha='right')
axes[1].grid(axis='y', linestyle='--', alpha=0.5)

plt.suptitle('LSTM Hyperparameter Optimisation — Test Set Comparison',
             fontsize=14, fontweight='bold')
plt.tight_layout()
plt.show()
